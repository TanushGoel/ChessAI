# %%
import torch
DEVICE = torch.device("mps")

# %%
from Board import Chess
Chess().show()

# %%
from Model import Model
MODEL = Model(Chess, DEVICE)
# MODEL.show()

# %%
from ML import Agent
AGENT = Agent(MODEL)

# %%
# AGENT.pretrain()
AGENT.train()

# %%
from GUI import Play, ChessGUI
Play(AGENT)

# %%
ChessGUI()

# %%
from IPython.display import IFrame
IFrame(src="https://lichess.org/tv/frame?theme=brown&bg=dark", width=400, height=440)
